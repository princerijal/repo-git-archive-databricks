# %%
# %sql
-- Create the External Location mapping your real Azure bronze container
CREATE EXTERNAL LOCATION IF NOT EXISTS `gitarchive_bronze_location`
URL 'abfss://bronze@stgithubarchive.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `gitarchive_storage_credential`);

# %%
# %sql
-- Create the data schema and bind it natively to your Azure storage URL
CREATE SCHEMA IF NOT EXISTS dbw_gitarchive.bronze
MANAGED LOCATION 'abfss://bronze@stgithubarchive.dfs.core.windows.net/';
